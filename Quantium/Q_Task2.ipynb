# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from matplotlib.dates import MONDAY
from matplotlib.dates import DateFormatter, MonthLocator, WeekdayLocator
from matplotlib.dates import date2num

# %%
df1=pd.read_csv('QVI_data-1.csv')

# %%
df1.head()
# Out:
#    LYLTY_CARD_NBR        DATE  STORE_NBR  TXN_ID  PROD_NBR  \
# 0            1000  2018-10-17          1       1         5
# 1            1002  2018-09-16          1       2        58
# 2            1003  2019-03-07          1       3        52
# 3            1003  2019-03-08          1       4       106
# 4            1004  2018-11-02          1       5        96
#
#                                 PROD_NAME  PROD_QTY  TOT_SALES  PACK_SIZE  \
# 0  Natural Chip        Compny SeaSalt175g         2        6.0        175
# 1   Red Rock Deli Chikn&Garlic Aioli 150g         1        2.7        150
# 2   Grain Waves Sour    Cream&Chives 210G         1        3.6        210
# 3  Natural ChipCo      Hony Soy Chckn175g         1        3.0        175
# 4          WW Original Stacked Chips 160g         1        1.9        160
#
#         BRAND              LIFESTAGE PREMIUM_CUSTOMER
# 0     NATURAL  YOUNG SINGLES/COUPLES          Premium
# 1         RRD  YOUNG SINGLES/COUPLES       Mainstream
# ...

# %%
df1['LYLTY_CARD_NBR'].iloc[-1:]
# Out:
# 99998    102093
# Name: LYLTY_CARD_NBR, dtype: int64

# %%
# Out:
# Empty DataFrame
# Columns: [LYLTY_CARD_NBR, DATE, STORE_NBR, TXN_ID, PROD_NBR, PROD_NAME, PROD_QTY, TOT_SALES, PACK_SIZE, BRAND, LIFESTAGE, PREMIUM_CUSTOMER]
# Index: []

# %%
df2=pd.read_csv('QVI_data-2.csv')

# %%
df2.head()
# Out:
#    LYLTY_CARD_NBR        DATE  STORE_NBR  TXN_ID  PROD_NBR  \
# 0          102093  2018-12-15        102  102090        62
# 1          102094  2019-05-16        102  102095       106
# 2          102094  2018-08-02        102  102092        80
# 3          102094  2018-11-24        102  102093       103
# 4          102094  2019-04-01        102  102094       104
#
#                                   PROD_NAME  PROD_QTY  TOT_SALES  PACK_SIZE  \
# 0          Pringles Mystery    Flavour 134g         2        7.4        134
# 1    Natural ChipCo      Hony Soy Chckn175g         1        3.0        175
# 2    Natural ChipCo Sea  Salt & Vinegr 175g         2        6.0        175
# 3      RRD Steak &         Chimuchurri 150g         2        5.4        150
# 4  Infuzions Thai SweetChili PotatoMix 110g         2        7.6        110
#
#        BRAND               LIFESTAGE PREMIUM_CUSTOMER
# 0   PRINGLES                RETIREES       Mainstream
# ...

# %%
# Out:
# Empty DataFrame
# Columns: [LYLTY_CARD_NBR, DATE, STORE_NBR, TXN_ID, PROD_NBR, PROD_NAME, PROD_QTY, TOT_SALES, PACK_SIZE, BRAND, LIFESTAGE, PREMIUM_CUSTOMER]
# Index: []

# %%
df3=pd.read_csv('QVI_data-3.csv')

# %%
df3.head()
# Out:
#    LYLTY_CARD_NBR        DATE  STORE_NBR  TXN_ID  PROD_NBR  \
# 0          205055  2019-06-15        205  204116        83
# 1          205057  2019-04-21        205  204117        25
# 2          205057  2019-06-02        205  204118        83
# 3          205058  2018-11-03        205  204119         8
# 4          205058  2018-11-19        205  204120        80
#
#                                  PROD_NAME  PROD_QTY  TOT_SALES  PACK_SIZE  \
# 0        WW D/Style Chip     Sea Salt 200g         2        3.8        200
# 1           Pringles SourCream  Onion 134g         1        3.7        134
# 2        WW D/Style Chip     Sea Salt 200g         2        3.8        200
# 3  Smiths Crinkle Cut  Chips Original 170g         2        5.8        170
# 4   Natural ChipCo Sea  Salt & Vinegr 175g         1        3.0        175
#
#         BRAND              LIFESTAGE PREMIUM_CUSTOMER
# 0  WOOLWORTHS  YOUNG SINGLES/COUPLES          Premium
# ...

# %%
df = pd.concat([df1, df2, df3], ignore_index=True)

# %%
df.head()
# Out:
#    LYLTY_CARD_NBR        DATE  STORE_NBR  TXN_ID  PROD_NBR  \
# 0            1000  2018-10-17          1       1         5
# 1            1002  2018-09-16          1       2        58
# 2            1003  2019-03-07          1       3        52
# 3            1003  2019-03-08          1       4       106
# 4            1004  2018-11-02          1       5        96
#
#                                 PROD_NAME  PROD_QTY  TOT_SALES  PACK_SIZE  \
# 0  Natural Chip        Compny SeaSalt175g         2        6.0        175
# 1   Red Rock Deli Chikn&Garlic Aioli 150g         1        2.7        150
# 2   Grain Waves Sour    Cream&Chives 210G         1        3.6        210
# 3  Natural ChipCo      Hony Soy Chckn175g         1        3.0        175
# 4          WW Original Stacked Chips 160g         1        1.9        160
#
#         BRAND              LIFESTAGE PREMIUM_CUSTOMER
# 0     NATURAL  YOUNG SINGLES/COUPLES          Premium
# 1         RRD  YOUNG SINGLES/COUPLES       Mainstream
# ...

# %%
df[df['LYLTY_CARD_NBR']==327012]
# Out:
# Empty DataFrame
# Columns: [LYLTY_CARD_NBR, DATE, STORE_NBR, TXN_ID, PROD_NBR, PROD_NAME, PROD_QTY, TOT_SALES, PACK_SIZE, BRAND, LIFESTAGE, PREMIUM_CUSTOMER]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264834 entries, 0 to 264833
# Data columns (total 12 columns):
# LYLTY_CARD_NBR      264834 non-null int64
# DATE                264834 non-null object
# STORE_NBR           264834 non-null int64
# TXN_ID              264834 non-null int64
# PROD_NBR            264834 non-null int64
# PROD_NAME           264834 non-null object
# PROD_QTY            264834 non-null int64
# TOT_SALES           264834 non-null float64
# PACK_SIZE           264834 non-null int64
# BRAND               264834 non-null object
# LIFESTAGE           264834 non-null object
# PREMIUM_CUSTOMER    264834 non-null object
# dtypes: float64(1), int64(6), object(5)
# memory usage: 24.2+ MB

# %%
df.isnull().sum()
# Out:
# LYLTY_CARD_NBR      0
# DATE                0
# STORE_NBR           0
# TXN_ID              0
# PROD_NBR            0
# PROD_NAME           0
# PROD_QTY            0
# TOT_SALES           0
# PACK_SIZE           0
# BRAND               0
# LIFESTAGE           0
# PREMIUM_CUSTOMER    0
# dtype: int64

# %%
df.describe()
# Out:
#        LYLTY_CARD_NBR      STORE_NBR        TXN_ID       PROD_NBR  \
# count    2.648340e+05  264834.000000  2.648340e+05  264834.000000
# mean     1.355488e+05     135.079423  1.351576e+05      56.583554
# std      8.057990e+04      76.784063  7.813292e+04      32.826444
# min      1.000000e+03       1.000000  1.000000e+00       1.000000
# 25%      7.002100e+04      70.000000  6.760050e+04      28.000000
# 50%      1.303570e+05     130.000000  1.351365e+05      56.000000
# 75%      2.030940e+05     203.000000  2.026998e+05      85.000000
# max      2.373711e+06     272.000000  2.415841e+06     114.000000
#
#             PROD_QTY      TOT_SALES      PACK_SIZE
# count  264834.000000  264834.000000  264834.000000
# mean        1.905813       7.299346     182.425512
# std         0.343436       2.527241      64.325148
# min         1.000000       1.500000      70.000000
# 25%         2.000000       5.400000     150.000000
# 50%         2.000000       7.400000     170.000000
# ...

# %%
df['BRAND'].value_counts()
# Out:
# KETTLE        41288
# SMITHS        31823
# DORITOS       28145
# PRINGLES      25102
# RRD           17779
# WOOLWORTHS    14757
# INFUZIONS     14201
# THINS         14075
# COBS           9693
# TOSTITOS       9471
# TWISTIES       9454
# OLD            9324
# GRNWVES        7740
# NATURAL        7469
# TYRRELLS       6442
# CHEEZELS       4603
# CCS            4551
# SUNBITES       3008
# CHEETOS        2927
# BURGER         1564
# FRENCH         1418
# Name: BRAND, dtype: int64

# %%
df['PACK_SIZE'].value_counts()
# Out:
# 175    66390
# 150    43131
# 134    25102
# 110    22387
# 170    19983
# 165    15297
# 300    15166
# 330    12540
# 380     6416
# 270     6285
# 210     6272
# 200     4473
# 135     3257
# 250     3169
# 90      3008
# 190     2995
# 160     2970
# 220     1564
# 70      1507
# 180     1468
# 125     1454
# Name: PACK_SIZE, dtype: int64

# %%
df.dtypes
# Out:
# LYLTY_CARD_NBR        int64
# DATE                 object
# STORE_NBR             int64
# TXN_ID                int64
# PROD_NBR              int64
# PROD_NAME            object
# PROD_QTY              int64
# TOT_SALES           float64
# PACK_SIZE             int64
# BRAND                object
# LIFESTAGE            object
# PREMIUM_CUSTOMER     object
# dtype: object

# %%
df.corr()
# Out:
#                 LYLTY_CARD_NBR  STORE_NBR    TXN_ID  PROD_NBR  PROD_QTY  \
# LYLTY_CARD_NBR        1.000000   0.950868  0.954919  0.001769  0.002296
# STORE_NBR             0.950868   1.000000  0.997593  0.002324  0.004766
# TXN_ID                0.954919   0.997593  1.000000  0.002558  0.004937
# PROD_NBR              0.001769   0.002324  0.002558  1.000000 -0.002043
# PROD_QTY              0.002296   0.004766  0.004937 -0.002043  1.000000
# TOT_SALES             0.001392   0.001672  0.001994 -0.160224  0.527788
# PACK_SIZE             0.000713   0.000259  0.000235 -0.230428  0.001761
#
#                 TOT_SALES  PACK_SIZE
# LYLTY_CARD_NBR   0.001392   0.000713
# STORE_NBR        0.001672   0.000259
# TXN_ID           0.001994   0.000235
# PROD_NBR        -0.160224  -0.230428
# PROD_QTY         0.527788   0.001761
# TOT_SALES        1.000000   0.369834
# PACK_SIZE        0.369834   1.000000

# %%
df_trial=df[(df['STORE_NBR'].isin([77,86,88]))]

# %%
df_trial.head()
# Out:
#        LYLTY_CARD_NBR        DATE  STORE_NBR  TXN_ID  PROD_NBR  \
# 73365           77000  2019-03-28         77   74911        18
# 73366           77000  2019-04-13         77   74912        69
# 73367           77000  2018-09-26         77   74910        36
# 73368           77001  2019-02-27         77   74913         7
# 73369           77001  2019-01-21         77   74914         9
#
#                                      PROD_NAME  PROD_QTY  TOT_SALES  \
# 73365           Cheetos Chs & Bacon Balls 190g         1        3.3
# 73366   Smiths Chip Thinly  S/Cream&Onion 175g         1        3.0
# 73367                       Kettle Chilli 175g         2       10.8
# 73368        Smiths Crinkle      Original 330g         2       11.4
# 73369  Kettle Tortilla ChpsBtroot&Ricotta 150g         2        9.2
#
#        PACK_SIZE    BRAND               LIFESTAGE PREMIUM_CUSTOMER
# 73365        190  CHEETOS  MIDAGE SINGLES/COUPLES           Budget
# ...

# %%
df_trial.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3974 entries, 73365 to 264833
# Data columns (total 12 columns):
# LYLTY_CARD_NBR      3974 non-null int64
# DATE                3974 non-null object
# STORE_NBR           3974 non-null int64
# TXN_ID              3974 non-null int64
# PROD_NBR            3974 non-null int64
# PROD_NAME           3974 non-null object
# PROD_QTY            3974 non-null int64
# TOT_SALES           3974 non-null float64
# PACK_SIZE           3974 non-null int64
# BRAND               3974 non-null object
# LIFESTAGE           3974 non-null object
# PREMIUM_CUSTOMER    3974 non-null object
# dtypes: float64(1), int64(6), object(5)
# memory usage: 403.6+ KB

# %%
df_trial.describe()
# Out:
#        LYLTY_CARD_NBR    STORE_NBR        TXN_ID     PROD_NBR     PROD_QTY  \
# count    3.974000e+03  3974.000000  3.974000e+03  3974.000000  3974.000000
# mean     1.040920e+05    85.667589  8.698404e+04    55.238802     1.926522
# std      1.988414e+05     3.640526  4.002005e+04    32.920617     0.324572
# min      7.700000e+04    77.000000  7.491000e+04     1.000000     1.000000
# 25%      8.607500e+04    86.000000  8.459625e+04    28.000000     2.000000
# 50%      8.624000e+04    86.000000  8.561550e+04    52.000000     2.000000
# 75%      8.819200e+04    88.000000  8.717075e+04    83.000000     2.000000
# max      2.373711e+06    88.000000  2.415841e+06   114.000000     5.000000
#
#          TOT_SALES    PACK_SIZE
# count  3974.000000  3974.000000
# mean      7.551233   180.395823
# std       2.438625    64.211425
# min       1.500000    70.000000
# 25%       6.000000   150.000000
# 50%       7.600000   170.000000
# 75%       9.200000   175.000000
# ...

# %%
df_trial['STORE_NBR'].value_counts()
# Out:
# 88    1873
# 86    1538
# 77     563
# Name: STORE_NBR, dtype: int64

# %%
sns.jointplot(x='STORE_NBR' , y='TOT_SALES',data=df_trial,kind='reg')
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df_trial['DATE'].value_counts()
# Out:
# 2019-02-03    23
# 2018-12-26    22
# 2019-04-20    21
# 2019-03-28    20
# 2019-03-31    20
# 2018-12-02    20
# 2018-09-12    19
# 2018-07-17    18
# 2018-10-29    18
# 2019-02-22    18
# 2018-12-19    17
# 2018-11-18    17
# 2019-05-26    17
# 2018-10-07    17
# 2019-03-22    17
# 2018-10-09    17
# 2018-11-23    17
# 2019-01-15    17
# 2018-08-06    16
# 2019-04-26    16
# 2018-09-25    16
# 2019-05-09    16
# 2019-03-13    16
# 2018-09-18    16
# 2018-07-07    16
# 2019-04-28    16
# 2019-06-18    16
# 2019-05-08    16
# 2018-09-15    16
# 2019-01-10    16
#               ..
# 2019-01-31     6
# 2019-04-12     6
# 2018-08-21     6
# 2018-07-15     6
# 2018-11-24     6
# 2019-04-27     6
# 2019-05-10     6
# 2018-12-15     6
# 2018-07-22     6
# 2018-12-01     6
# 2018-11-15     6
# 2019-04-17     6
# 2018-12-12     6
# 2018-12-28     5
# 2018-10-08     5
# 2018-10-27     5
# 2019-06-02     5
# 2018-08-31     5
# 2018-09-21     5
# 2019-01-12     5
# 2018-09-13     5
# ...

# %%
df_trial['DATE'] =  pd.to_datetime(df_trial['DATE'],format='%Y-%m-%d')
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
df_trial.set_index('DATE', inplace=True)

# %%
df_trial.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3974 entries, 2019-03-28 to 2018-12-14
# Data columns (total 11 columns):
# LYLTY_CARD_NBR      3974 non-null int64
# STORE_NBR           3974 non-null int64
# TXN_ID              3974 non-null int64
# PROD_NBR            3974 non-null int64
# PROD_NAME           3974 non-null object
# PROD_QTY            3974 non-null int64
# TOT_SALES           3974 non-null float64
# PACK_SIZE           3974 non-null int64
# BRAND               3974 non-null object
# LIFESTAGE           3974 non-null object
# PREMIUM_CUSTOMER    3974 non-null object
# dtypes: float64(1), int64(6), object(4)
# memory usage: 372.6+ KB

# %%
plt.figure(figsize=(20,5))
df_trial.TOT_SALES.plot(title='TOTAL SALES')
plt.show()

# %%
plt.figure(figsize=(20,5))

df_date = df_trial['2019-3': '2019-6']
df_date.TOT_SALES.plot(title='Trial period (SALES)')

# %%
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
'''# Create figure and plot space
fig, ax = plt.subplots(figsize=(12, 12))

# Add x-axis and y-axis
ax.bar(df_date.index.values,
       df_date['TOT_SALES'],
       color='blue')

# Set title and labels for axes
ax.set(xlabel="Date",
       ylabel="TOTAL SALES",
       title="SALES")

plt.show()

'''
# Out:
# '# Create figure and plot space\nfig, ax = plt.subplots(figsize=(12, 12))\n\n# Add x-axis and y-axis\nax.bar(df_date.index.values,\n       df_date[\'TOT_SALES\'],\n       color=\'blue\')\n\n# Set title and labels for axes\nax.set(xlabel="Date",\n       ylabel="TOTAL SALES",\n       title="SALES")\n\nplt.show()\n\n'

# %%
plt.figure(figsize=(20,5))

df_date = df_trial['2019-3' :'2019-6']
df_date.TXN_ID.plot(title='Transactions')

# %%
#df_date.groupby(["TOT_SALES"]).sum().sort_values("TOT_SALES", ascending=False)
